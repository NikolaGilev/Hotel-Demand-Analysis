# %% [markdown]
# binary and multiclass classification on has_free_cancelation and sustainability level.
# clustering on price + distance from center
# regression - tree?

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/hotels_daily_final.csv')
df
# Out:
#                                                     name  \
# 0                     The Pavilions Amsterdam, The Toren
# 1                                      Sonder Park House
# 2                   Hotel Jansen Amsterdam Bajeskwartier
# 3                                               AmicitiA
# 4                                       Hotel Washington
# ...                                                  ...
# 54909  Schöne 2 1/2 Zimmer Wohnung im Herzen von Dort...
# 54910                                        schlafgut24
# 54911                       3 Zimmer Wohnung in Dortmund
# 54912                           Wohnung Nähe Uni,Stadion
# 54913                                          FeWo Born
#
#                                location       price  \
# 0      Amsterdam City Center, Amsterdam  MKD 14,351
# 1                   Oud Zuid, Amsterdam   MKD 8,890
# 2                       Oost, Amsterdam   MKD 5,267
# 3      Amsterdam City Center, Amsterdam   MKD 1,848
# 4                   Oud Zuid, Amsterdam   MKD 3,080
# ...                                 ...         ...
# 54909    Dortmund City Centre, Dortmund  MKD 11,726
# 54910                          Dortmund   MKD 7,331
# 54911                          Dortmund  MKD 11,704
# 54912                          Dortmund   MKD 5,211
# 54913                          Dortmund  MKD 13,270
#
#                                date  stars distance_from_center  \
# 0      ['2024-02-01', '2024-02-02']    4.0   0.6 km from center
# 1      ['2024-02-01', '2024-02-02']    4.0   1.7 km from center
# 2      ['2024-02-01', '2024-02-02']    NaN   4.2 km from center
# 3      ['2024-02-01', '2024-02-02']    NaN   1.2 km from center
# 4      ['2024-02-01', '2024-02-02']    2.0   2.1 km from center
# ...                             ...    ...                  ...
# 54909  ['2025-01-31', '2025-02-01']    NaN   0.6 km from center
# 54910  ['2025-01-31', '2025-02-01']    NaN  10.9 km from center
# 54911  ['2025-01-31', '2025-02-01']    NaN     3 km from center
# 54912  ['2025-01-31', '2025-02-01']    NaN     5 km from center
# 54913  ['2025-01-31', '2025-02-01']    NaN   1.1 km from center
#
#       num_external_reviews booking_user_ratings  avg_user_ratings  \
# 0            1,044 reviews            Excellent               8.9
# 1            3,190 reviews                 Good               7.5
# 2            1,155 reviews            Very Good               8.3
# 3            1,820 reviews                 Good               7.1
# 4            2,205 reviews                 Good               7.3
# ...                    ...                  ...               ...
# 54909           11 reviews            Excellent               8.6
# 54910           16 reviews          Exceptional               9.6
# 54911            3 reviews            Very Good               8.0
# 54912                  NaN                  NaN               NaN
# 54913                  NaN                  NaN               NaN
#
#             airport_taxi     travel_sustainable_level  has_free_cancelation
# 0      Limited-time Deal  Travel Sustainable Level 3+                 False
# 1        No airport taxi                          NaN                  True
# 2        No airport taxi   Travel Sustainable Level 3                  True
# 3        No airport taxi                          NaN                  True
# 4        No airport taxi                          NaN                 False
# ...                  ...                          ...                   ...
# 54909    No airport taxi                          NaN                 False
# 54910    No airport taxi   Travel Sustainable Level 2                 False
# 54911    No airport taxi                          NaN                 False
# 54912    No airport taxi                          NaN                 False
# 54913    No airport taxi                          NaN                 False
#
# [54914 rows x 12 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Print out the data and see which columns need cleaning

# %%
[print(d, df[d].unique()) for d in df.columns]
# Out:
# name ['The Pavilions Amsterdam, The Toren' 'Sonder Park House'
#  'Hotel Jansen Amsterdam Bajeskwartier' 'AmicitiA' 'Hotel Washington'
#  'Vita Nova' 'Mps Holland' 'Budget Trianon Hotel' 'Belfort Hotel'
#  'Amsterdam Hotelboat' 'Hotel Amsterdam Inn' 'The Alfred Hotel'
#  'XO Hotel Inner' 'The Concert Hotel' 'De Bedstee Boutique Capsules'
#  'Blossoms City Hotel' 'Urban Lodge Hotel' 'Hotel Espresso' 'Felicitas'
#  'Hotel Ben Centre' 'MAX Hotel Amsterdam' 'The Flying Pig Uptown'
#  'B&B HutSpot' 'Hotel Fogo' 'The Cabin @ MPS Noorderzon'
#  'Hotel City Garden Amsterdam'
#  'Conscious Hotel Amsterdam City - The Tire Station'
#  'ibis Styles Amsterdam City' 'ClinkNOORD Hostel' 'Hotel Parkview'
#  'Hotel Allure' 'Hotel Atlantis Amsterdam' 'Hotel New Kit'
#  'The Times Hotel' 'Ruby Emma Hotel Amsterdam'
#  'The Arcade Hotel Amsterdam' 'Park Inn by Radisson Amsterdam City West'
#  'Hampton By Hilton Amsterdam Arena Boulevard'
#  'Hampton by Hilton Amsterdam Centre East' 'Boutique Hotel Oosteinde'
#  'YOTEL Amsterdam' 'Mercure Amsterdam Sloterdijk Station' 'Hotel Levell'
#  'Joy Hotel' 'Hotel Iron Horse Amsterdam' 'XO Hotels Park West'
#  'Hotel Abba' 'Hotel Goodnight Antwerp' 'Citybox Antwerp' 'Casa Amor'
#  'B&B HOTEL Antwerpen Centrum' 'ibis budget Antwerpen Centraal Station'
#  'ibis Antwerpen Centrum' 'Hampton By Hilton Antwerp Central Station'
#  'Hotel Indigo Antwerp City Centre, an IHG Hotel'
#  'Suite city center in quiet street & airco' 'prizeotel Antwerp-City'
#  'NH Collection Antwerp Centre' 'Hotel National Antwerp' 'Beaux ARTS'
#  'Astoria Hotel Antwerp' 'Crowne Plaza Antwerpen, an IHG Hotel'
#  'Hotel Opera Antwerpen Centrum' 'Hotel Rubens-Grote Markt'
#  'Mercure Antwerp City Centre' 'U Eat & Sleep Antwerp'
#  'Holiday Inn Express Antwerp - City Centre, an IHG Hotel'
#  'Park Inn by Radisson Antwerpen' 'B&B HOTEL Antwerpen Zuid'
#  'Holiday Inn Express Antwerpen City North, an IHG Hotel'
#  'Sapphire House Antwerp, Autograph Collection'
#  'Radisson BLU Astrid Hotel, Antwerp' 'Mercure Antwerp City South'
#  'Studio Anvers' 'Maison Nationale City Flats & Suites'
#  'Leonardo Hotel Antwerpen' 'Pink Pigeon' "Simone's Kitchen B&B"
#  'Hotel Docklands' 'Museum Suites' 'Century Hotel Antwerpen Centrum'
#  'HotelO Kathedral' 'Hilton Antwerp Old Town'
#  'KAOZ Highstreet The Luxury Loft' 'A-STAY Antwerp' 'Luxury Suites Royal'
#  'PREMIER SUITES Antwerp' "GiGi Home's" 'Luxury Suites Meir'
#  'Arass Hôtel & Business Flats' 'Radisson Hotel Antwerp Berchem'
#  'Luxury Suites Palace' 'a&o Dortmund Hauptbahnhof' 'Moxy Dortmund City'
#  'NH Dortmund' 'Hotel Excelsior Dortmund Hauptbahnhof' 'LivInn Hotel'
#  'prizeotel Dortmund-City' 'Hampton By Hilton Dortmund Phoenix See'
#  'ibis budget Dortmund West' 'Hotel Union'
#  'Residence Inn by Marriott Dortmund City' 'Days Inn Dortmund West'
#  'Hotel Unique Pearl' 'Dorint An den Westfalenhallen Dortmund'
#  'Home Hotel' 'Holiday Inn Express Dortmund, an IHG Hotel'
#  'Mercure Hotel Dortmund Centrum' 'DJH Jugendgästehaus Adolph Kolping'
#  'Hotel der Lennhof' 'Tondose Apartment' 'Hotel Esplanade Dortmund'
#  'B&B Hotel Dortmund-City' 'Leonardo Hotel Dortmund'
#  'Basecamp Hotel Dortmund' 'PS-Projektentwicklung'
#  'BRIGHT Dortmund City Center' 'Coffee Fellows Hotel Dortmund'
#  'Pension Sölde' 'Courtyard by Marriott Dortmund' "l'Arrivée Hotel & Spa"
#  'Moods Hotel Dortmund' 'Deluxe Wohnungen Dortmund Mitte'
#  'NP Hotel Königshof' 'Parkhotel Wittekindshof' 'Akzent Hotel Körner Hof'
#  'ibis Hotel Dortmund City' 'TM Aparts' 'S & D Hotel Dortmund'
#  'Design Apartments 1' 'Hotel Senator' 'NYCE Hotel Dortmund Thier Galerie'
#  'G & L City Rooms' 'Hotel Prinsenhof Amsterdam'
#  'Holiday Inn Express Amsterdam Arena Towers, an IHG Hotel'
#  'The Delphi - Amsterdam Townhouse' 'Motel One Amsterdam'
#  'Mercure Hotel Amsterdam West' 'Olympic Hotel' 'Via Amsterdam'
#  'Park Centraal Amsterdam, part of Sircle Collection' 'W Amsterdam'
#  'Hotel V Frederiksplein' 'nhow Amsterdam Rai'
#  'Holiday Inn Express Amsterdam - City Hall, an IHG Hotel'
#  'Leonardo Royal Hotel Amsterdam' 'Qbic Amsterdam WTC'
#  'Holiday Inn Express Amsterdam - South, an IHG Hotel'
#  'Sofitel Legend The Grand Amsterdam' 'Jaz in the City Amsterdam'
#  'Apollo Hotel Amsterdam, a Tribute Portfolio Hotel'
#  'DoubleTree by Hilton Amsterdam Centraal Station'
#  'Holiday Inn Amsterdam - Arena Towers, an IHG Hotel'
#  'Moxy Amsterdam Houthavens' 'citizenM Amsterdam South'
#  'Holiday Inn Express Amsterdam - Sloterdijk Station, an IHG Hotel'
#  'The Social Hub Amsterdam City' 'Mövenpick Hotel Amsterdam City Centre'
#  'the niu Fender' 'OZO Hotels Arena Amsterdam'
#  'Max Brown Hotel Canal District, part of Sircle Collection'
#  'Hotel Casa Amsterdam'
#  'Holiday Inn Express Amsterdam - North Riverside, an IHG Hotel'
#  'Hotel V Fizeaustraat' 'Mercure Amsterdam North Station'
#  'Max Brown Hotel Museum Square, part of Sircle Collection' 'Volkshotel'
#  'Mister Highland Hotel' 'Aparthotel Adagio Antwerp City Center'
#  'ibis budget Antwerpen Port' 'YUST Antwerp'
#  'Lindner Hotel Antwerp, part of JdV by Hyatt' 'The ASH'
#  'Opera-square Apartments in the Heart of Antwerp'
#  'Van der Valk Hotel Antwerpen' 'Your home in antwerpen N7'
#  'Tulip Inn Antwerpen' 'Cozy Apartment on Best Location in Antwerp'
#  'P6 Antwerp' 'Hotel Banks' 'Antwerp Central Youth Hostel'
#  'Smartflats - Avenue Antwerp' 'Leonardo Hotel Antwerp The Plaza'
#  'Beautiful Cozy Apartments in the Heart of Antwerp' 'The Red With Pearls'
#  'stays design Hotel Dortmund' 'IntercityHotel Dortmund'
#  'Best Western Hotel Dortmund Airport' 'Hotel Ambiente' 'Hotel Annis M&P'
#  'Apartment in the center' 'Big Apartments' 'City-Pension-Dortmund'
#  'Hotel- Restaurant Kerzan´s'
#  'Apartments in the city center I private parking I digital access I home2share'
#  'Zentrale Wohnung in Dortmund' 'DO One Bedroom Flat'
#  'Motel One Amsterdam-Waterlooplein' 'Aadam Hotel Wilhelmina'
#  'Courtyard by Marriott Amsterdam Arena Atlas' 'ibis Amsterdam City West'
#  'Leonardo Hotel Amsterdam Rembrandtpark'
#  'Leonardo Hotel Amsterdam City Center' 'Best Western Amsterdam'
#  'Bastion Hotel Amsterdam Zuidwest' 'The Social Hub Amsterdam West 4 star'
#  'Catalonia Vondel Amsterdam'
#  'Corendon Amsterdam New-West, a Tribute Portfolio Hotel'
#  'Novotel Amsterdam City' 'PREMIER SUITES PLUS Amsterdam'
#  'The July - Twenty Eight' 'Bastion Hotel Amsterdam Amstel'
#  'Hotel Library Amsterdam' 'Multatuli Hotel'
#  'Kathedraallogies Drie Koningen' 'Trip Inn Eden Antwerpen'
#  'Condo Gardens Antwerp' 'Hotel1875' 'Hyllit Hotel'
#  'Japie rooms - in the heart of Antwerp' 'Leeuwerik sdudio'
#  "Hotel 'T Sandt" 'Sān home’s' 'Sam in Antwerp' 'Hotel Matelote'
#  'Mercure Hotel Dortmund Messe' 'Hotel Unique Dortmund Hauptbahnhof'
#  'Mercure Hotel Dortmund City' 'ibis Styles Dortmund West'
#  'Radisson Blu Hotel Dortmund' 'NYCE Hotel Dortmund City'
#  'The Grey Design Hotel' 'Ringhotel Drees'
#  'Zentrale Unterkunft in Dortmund City' 'Hotel NeuHaus'
#  'Hotel Biedermeier' 'Canal Wow Suites Amsterdam' 'BLAUWE HOORN'
#  'The Highlander' 'Passengership Avanti' 'Hotel Hortus'
#  'Swissôtel Amsterdam' 'Hotel Sint Nicolaas' 'Mozart Hotel'
#  'Hotel Pontsteiger' 'A-Train Hotel' 'The Highland House'
#  'DoubleTree by Hilton Amsterdam - NDSM Wharf'
#  'Radisson Blu Hotel, Amsterdam City Center' 'NH Amsterdam Zuid'
#  'Budget Hotel Tourist Inn' 'Hotel Estheréa' 'Hotel Flipper Amsterdam'
#  "Sara's Boutique Hotel" 'Amsterdam House Hotel' 'Generator Amsterdam'
#  'Amsterdam Wiechmann Hotel' 'Luxury Suites Castel'
#  'Luxury Suits Historic Center' 'The 1880 Residence by Domani Hotels'
#  'Luxury Rooms' 'Hotel Carlton' 'Design Apartments 2' 'Hotel Fürst Garden'
#  'Studio 229' 'Plantage Garden Apartments' 'Bunk Hotel Amsterdam'
#  'Hotel Isis' 'easyHotel Amsterdam Arena Boulevard'
#  'New West Inn Amsterdam' 'Crown Hotel' 'Hotel Vondel Garden City Centre'
#  'The Flying Pig Downtown' 'G Experience Hotel' 'Budget Hotel Ben'
#  'Bens The Highdocks' 'Conscious Hotel Westerpark'
#  'B&B Amsterdam Holy Dove' 'House of Amstel' 'Conscious Hotel Vondelpark'
#  'Travel Hotel Amsterdam' 'Guest House Amsterdam' 'De Mallemoolen'
#  'Stayokay Hostel Amsterdam Vondelpark' 'Hotel Torenzicht'
#  'Facade Hotel Amsterdam' 'Hostel Utopia' 'Hotel La Belle Vue'
#  'Family Hotel Kooyk' 'Princess Hostel Leidse Square Amsterdam'
#  'Luxury Suites Central' 'Luxury Suites Boutique'
#  'Garden Suite in city center' 'Sint-Jans Appartments' "Nammos Home's"
#  'Beautiful sunny apartment' 'Luxury Suites' "Coco's"
#  'Сarnot Apartments ZOO Area' 'Steigenberger Dortmund'
#  'Apartement Central 40qm Wi-Fi free Parking calm back house 10B'
#  'B&B Hotel Dortmund Messe' 'Hotel Larende' 'Pension Homeland' 'Ecomama'
#  'Melrose Hotel' 'Amsterdam Downtown Hotel'
#  'The Lancaster Hotel Amsterdam' 'Hotel Manofa' 'The Unbound Amsterdam'
#  "LouLou Home's" 'XO Hotels Infinity' 'NL Hotel District Leidseplein'
#  'The Social Hub Amsterdam West' 'Hotel Internationaal'
#  'Hans Brinker Hostel Amsterdam' 'Hotel de Westertoren'
#  'Huygens Place Amsterdam' 'Hotel Aalders' 'THIS HO(S)TEL'
#  'Q-Factory Hotel' 'Citiez Hotel Amsterdam'
#  'Anantara Grand Hotel Krasnapolsky Amsterdam' 'Heart of Amsterdam Hotel'
#  'Hotel Fita' 'De L’Europe Amsterdam – The Leading Hotels of the World'
#  'Hapimag Apartments Amsterdam' 'Hotel Cornelisz'
#  'Luxury Suites Cathedral' 'Luxury Suites Riverside Residence'
#  'Royal South - Apartment Antwerp with Parkview'
#  'Apartement Central 40qm Wi-Fi free Parking calm back house 10C'
#  'Central 40qm Wi-Fi free Parking calm back house 10A'
#  'Amsterdam Marriott Hotel' 'Hotel Damsquare' 'Hotel Mosaic Appartments'
#  'Hotel Mosaic City Centre' 'City Hotel Amsterdam'
#  'Hotel Continental Amsterdam' 'Park Plaza Victoria Amsterdam'
#  'Tivoli Doelen Amsterdam Hotel'
#  'Residence Inn by Marriott Amsterdam Houthavens' 'Hotel CC'
#  'Hotel Diamonds and Pearls' 'YAYS Antwerp Opera' 'Antwerp Harbour Hotel'
#  'Gulde Schoen Luxury Studio-apartments' 'G & L Hotel Dortmund'
#  'Hotelboat Angeline' 'Alp Hotel'
#  'Andaz Amsterdam Prinsengracht - a concept by Hyatt' 'Hotel V Nesplein'
#  'Crowne Plaza Amsterdam - South, an IHG Hotel' 'Hotel Roemer Amsterdam'
#  'The Muse Amsterdam - Boutique Hotel' 'Beautiful studio' 'Theater Hotel'
#  'Ambassador Suites Antwerp' 'Hotel Antwerp Billard Palace'
#  'Opera Square Apartments in the Heart of Antwerp' "Dieckmann's Hotel"
#  'Hotel In der Meile' 'Dortmund City Wohnung 85/7'
#  'Sellmann´s Boutique Hotel' 'City Wohnung Zentral 89-10'
#  'Idyllisches Nest über den Dächern' 'Hotel Drei Kronen'
#  'Moderne Wohnung Messe Uni Stadion'
#  'Appartement House Dortmund "Studio App SANSIBAR"'
#  'Phöenixpalace Whirlpool & Infarotsauna' 'Road Stop Dortmund'
#  'City Flats Dortmund' 'Modernes Appartement Nähe City'
#  'Ferienwohnung Dortmund - Elias - Adults Only' 'Hotel Specht'
#  'Lea´s Apartment´s' 'FeWo Born'
#  'Nähe BVB Stadion Dortmund City Innenstadt'
#  'Mercure Amsterdam City Hotel' 'Element Amsterdam'
#  'Bilderberg Garden Hotel' 'Hilton Amsterdam'
#  'Renaissance Amsterdam Hotel' 'Postillion Hotel Amsterdam'
#  'Eric Vökel Boutique Apartments - Amsterdam Suites'
#  'Grand Hotel Amrâth Amsterdam' 'Qstay Good Living Apartments'
#  'Casa ENRICO' 'The Museum - Au Lit, Jérôme!'
#  'Gepflegte Wohnungen in der Innenstadt'
#  'NH Collection Amsterdam Barbizon Palace' 'NEWLY OPENED - Parklane Hotel'
#  'Met Hotel Amsterdam' 'Eden Hotel Amsterdam' 'Hotel Damrak Inn'
#  'NH Collection Amsterdam Flower Market' 'NH Amsterdam Caransa'
#  'Hyatt Regency Amsterdam' 'Kaai11, Boutique Hotel Riverview'
#  'Smartflats - Raphael Suites'
#  'Botanic Sanctuary Antwerp - The Leading Hotels of the World'
#  'Apartment in zentraler Lage zur Dortmunder Innenstadt'
#  'NH Amsterdam Schiller' 'Kimpton De Witt Amsterdam, an IHG Hotel'
#  'NH Amsterdam Leidseplein' 'The Hoxton, Lloyd Amsterdam' 'France Hotel'
#  'Herengracht Private room with canal view' 'citizenM Amstel Amsterdam'
#  'BONJOUR Apartments Сentre 3' 'Hotel Pagi'
#  'Gemütliches Apartment direkt am Hafen von Dortmund'
#  'Apartment direkt am Hafen - mit Terrasse und UHD TV' 'TWENTY FIVE Rooms'
#  'Hotel 83' 'Koopermoolen' 'Botel Zwaantje' 'Hotel Sharm' 'Anna Maria II'
#  'B in Antwerp' 'Hotel Postkutsche' 'Bob W Amsterdam Noord'
#  'Kapitein Anna' 'Delta Hotel City Center' 'Quentin England Hotel'
#  'Chassé Hotel Residency' 'Belgiëlei 94' 'Hotel Les Nuits'
#  'Quartier Le Sud' 'Rock Lobster City Lodge' 'The Blue Parrot' 'The Suit'
#  'Prinsengracht Hotel' 'Hotel Van Gogh' 'Grand Canal Boutique Hotel'
#  'The Banker Antwerpen - Free Parking' 'B&B Suites FEEK'
#  'The ED Amsterdam' 'Nova Hotel' 'Hotel La Bohème' 'Train Lodge Amsterdam'
#  'ibis Amsterdam Centre Stopera' 'OZO Hotels Cordial Amsterdam'
#  'Hotel Prins Hendrik' 'Acostar Hotel' 'Hotel Oscar'
#  'Cosy apart Antwerpen center3' 'Viktoria HOSTEL' 'Apartments Bex.'
#  'B&B The Baron' 'Gildenhof An den Westfalenhallen Dortmund'
#  'ibis Amsterdam Centre' 'ibis Styles Amsterdam Central Station'
#  'Hotel Dwars' 'Hotel Urban Dreams' 'Charming Suites Jan Zonder Vrees'
#  'Hotel Mezonvin' 'The Old Beech' 'The Light Blue Parrot'
#  'Budget Hotel Neutraal' 'Hotel Jimmy' 'The July - Boat & Co' 'B&B Kava'
#  'Antwerp Business Suites' 'Appartement met uitzicht op het MAS'
#  'Bed & Breakfast Exterlaer' 'Harmony House' 'B&B Maryline' 'Hotel Pilar'
#  'Vrijdagmarkt by Lit d’Art' 'Luxury Suites Arendshof'
#  'Boutique Apartment Scheldt' 'LePalaisduSud' 'XO Hotels Blue Square'
#  'The Old Nickel Hotel' 'Hotel Park Plantage' 'V Lofts'
#  'The Hendrik Square Residence' 'NH City Centre Amsterdam'
#  'Tribe Amsterdam City' 'Apartment 229' 'Aston City Hotel'
#  'The Capital Street Lodge' 'The Grand Apartment. Center of Antwerp'
#  'The Capital Street Triplex' 'B&B Parkhuys' 'Brial apartment 2 bedrooms,'
#  'Le Marnix' 'The Black Pants' 'Hotel Sebastians'
#  'Boutique Hotel Notting Hill'
#  'Tempel Triplex & Duplex at Historic Heart of Antwerp'
#  'Kyoto Suites - Center Antwerp!' 'The Soul Antwerp' 'B&B BedStarLine'
#  'Cityview Apartment w/Terrace'
#  'Apartments Plantin 3 sleeping rooms 2 bathrooms.' '"2600"'
#  'Isabel Apartments' '1 slaapkamerappartement' 'Roosevelt Apartments.'
#  'Huize Amoras' 'august' 'Novotel Antwerpen' 'Suikerrui 16 App 102'
#  'Designed Penthouse, Amsterdam city center' 'Hotel Verdi'
#  'Hotel Corner House' 'Hotel tip butique' 'De Keyser Hotel'
#  'Top located cozy apartments next to KMSKA' 'Hotel Riga' 'Hotel FRANQ'
#  'Joseph(ine)' 'Boutique hotel Maison Emile' 'Hotel Julien' 'Flora'
#  'FMS Logie' 'Hotel Colvenier' 'Cabosse, Suites & Spa'
#  'Boho apartment Antwerp south' 'Antwerp City Hostel' 'Boomerang Antwerp'
#  'Leonardo Boutique Museumhotel' 'Hotel Nes' 'XO Hotels City Centre'
#  'ibis Styles Amsterdam Amstel' '22b&b' 'Mañana Mañana' 'Musa Antwerp'
#  'Bright Apartments In The Heart Of Antwerp' 'Hotel Restaurant Old Bridge'
#  'Hotel The Bird' 'Hotel Old Quarter' 'Hotel Mai Amsterdam'
#  'BnB Antwerp Centrum' 'Eelhouse private studio' 'Cityview Hotel'
#  "JamieK's BnB" 'Penth A Apartment in Heart of Antwerp'
#  'Villa Mercurius Grote Markt'
#  'City PENTHOUSE, rooftop terrace, free NETFLIX, wifi and airco'
#  'Hotel Not Hotel Amsterdam' 'Best Western Dam Square Inn'
#  'CityHub Amsterdam' 'NH Amsterdam Museum Quarter'
#  'Belga Apartment 3 bedrooms.' 'Central Park Apartments'
#  'Luxury Suites Princess' 'Blue Lagoon in the city' 'Apple Inn Hotel'
#  'Schöne Apartment in Dortmund Bövinghausen' 'Overkamp'
#  'Zur schönen Aussicht I 90 m² I Idyllisch I Zuhause' 'TM Suites'
#  'Großzügige Neubauwohnung mit Blick auf den Phönix-See'
#  'Appartement House Dortmund "Lounge Appartement"'
#  '3 Zimmer Wohnung in Dortmund' 'TM Studio'
#  'FeWo Hafen: Apartment in a Great Location'
#  'Appartements DW16~17~19 in Dortmund' 'Royal Plaza Hotel Amsterdam'
#  'Quentin Amsterdam Hotel' 'Hotel Doria'
#  'MEININGER Hotel Amsterdam Amstel' 'Hotel & bar Royal taste Amsterdam'
#  'Hotel Heye 130' 'Campanile Hotel & Restaurant Amsterdam Zuid-Oost'
#  'City Wohnung Zentral 89-11' 'Van der Valk Hotel Amsterdam - Amstel'
#  'WestCord Fashion Hotel Amsterdam' 'Mercedes Bed&Breakfast Amsterdam'
#  'Bacchus Antwerpen - Rooms & Apartments' 'Le Leopold' 'Via Suites'
#  'Krisotel' 'Four Elements Hotel' 'B&B Luxe Suites 1-2-3'
#  'Stayokay Hostel Amsterdam Oost' 'Boutique Hotel View'
#  'Inntel Hotels Amsterdam Centre' 'Hotel Luxer' 'The Hoxton, Amsterdam'
#  'The Bank Hotel' 'Golden Mansion Aparthotel' 'Guesthouse Bernardin'
#  'Adam Suites Hotel' 'BnB 117' 'WestCord Art Hotel Amsterdam 3 stars'
#  'COMMUNE suites' 'INNSiDE by Meliá Amsterdam'
#  'Pestana Amsterdam Riverside' 'Hotel & Wellness Zuiver'
#  'Romantische Studio in Harmoniewijk' 'Rho Hotel'
#  'Pillows Grand Boutique Hotel Maurits at the Park - Small Luxury Hotels'
#  'Fletcher Hotel Amsterdam' 'Ice studio' 'Luxury Suites Amsterdam'
#  'Breitner House' 'NH Collection Barbizon Palace Apartments'
#  'Marnix Classic: Group Getaway' 'Waldorf Astoria Amsterdam'
#  'Luxury apartment in the city center'
#  'Unique Ground-Floor Appartment with Beautiful Garden in Amsterdam'
#  'Amigo Hotel' 'canal house, best place Amsterdam' 'Perl' 'ADA'
#  'Dream Hotel Amsterdam'
#  'Hotel Okura Amsterdam – The Leading Hotels of the World'
#  'Ciao Papa Hotel Amsterdam Central Station' 'Grand Hotel Downtown'
#  'WestCord City Centre Hotel'
#  'nice and cosy place with jacuzzi and sauna to relax in the centre of antwerp'
#  'Your homestay in a bibliophile mansion'
#  'Modernes Apartment auf 2 Etagen in ruhiger Lage zentral zu Stadion und Westfalenhallen'
#  'MEININGER Hotel Amsterdam City West' 'Rooms25' 'Nadia Hotel'
#  'NH Amsterdam Noord' 'Amadi Park Hotel' 'INK Hotel Amsterdam - MGallery'
#  'BTFL Living Antwerp' 'Studio Eelhouse'
#  'Skotel Amsterdam, Hotelschool The Hague' 'Voyagers Amsterdam'
#  "Blaine's: A B&B and private dining...."
#  'Sotel Amsterdam Central Station' 'Hotel Arena' 'Van Lerius studio'
#  'Frank’s and Chong’s excellent location' 'Hotel Jakarta Amsterdam'
#  '85I Dortmund City Wohnung' 'The Diem Amsterdam' 'Hotel Atlanta'
#  'Upstairs' 'Nine Streets Inn' 'Hotel Rubenshof' 'The White Tulip Hostel'
#  'De Durgerdam' 'BackStage Hotel' 'Amsterdam Hostel Sarphati' 'Cocomama'
#  'Cozy Antwerp - Cityview Studio FREE PARKING'
#  'SLEEP INN - Black and Gold Loft Antwerp Cityview'
#  'Apartement Central 55qm Wi-Fi free Parking calm back house 10D'
#  'hotel calisto' 'Authentic Ship with a stunning view!'
#  'Rembrandt Square Hotel' 'WesterVilla' 'Puur B&B' 'The Greenhouse'
#  "'t Hotel" 'Room Mate Aitana' 'Bkenkember Apart' 'Fashion City 2'
#  'Kloosterloft' "Charlie's Bed & Breakfast" 'Thai Time Wellness'
#  'PS5+55 Zoll 4K Fernseher - Gaming Apartment'
#  '2 Room Messe Kongress Stadion'
#  'Apartment direkt am Hafen - mit UHD TV und Netflix' 'SUPPER Hotel'
#  'The College Hotel Amsterdam, Autograph Collection'
#  'Conservatorium Hotel' 'The Roof - Rooftop appt in historical center'
#  'AmsterHome Hotel' 'GROGO DUPLEX APPARTMENT(CENTRE OF ANTWERP)'
#  'TRUTH für 3 - Moderne Küche - Smart TV - Teppichboden' 'Dock 29'
#  'Antwerp For Two B&B' 'Jan Luyken Amsterdam'
#  'OZO Hotels Armada Amsterdam' 'CampIn Hotel' 'XO Hotels Couture'
#  'Panoramic Antwerpen Centrum' 'EMPIRIC Keizersgracht'
#  'Cityden BoLo District' 'CITYSTAY' 'City Wohnung Zentral 85-5'
#  'Monet Garden Hotel Amsterdam' 'Hotel van Gelder'
#  'B & B Tulp Amsterdam Noord' 'B&B Sint-Mariaburg'
#  'The Enlightened House Luxury Suites'
#  'The View - spacious 2 bdr appt in with view'
#  'Amsterdam House of Arts & Crafts' 'Houseboat Sophia' 'Logies Lapin'
#  'Spacious' 'Outside Inn' 'Suite 11' 'The Wonder Shore' 'The Mansion'
#  'Bridge Inn' 'Klavergeluk' 'B&B House No 7' "Marijke's guestroom"
#  'Cozy Canal Studio' 'All-in Penthouseroom' 'Dortmund City Wohnung 85/3'
#  'Westfalenpark Apartment with terrace and free parking'
#  'Wohnung am Phönixsee' 'The Panorama Suite (Mandelahuisje)'
#  'Amsterdam Houseboat amstel'
#  'Neubauwohnung mit Panoramablick auf den Phönixsee'
#  'Dortmund City Wohnung 85/6' 'Paradise Apartments'
#  'TRUTH Studio für 3 - Küche - Top Internet - Parkplatz - Modern'
#  'Wohnung Nähe Uni,Stadion' 'schlafgut24' 'Monteur-Bungalow Dortmund'
#  'TRUTH - Kingsize Bett - Smart TV - Modern - Top Anbindung'
#  'Van der Valk Hotel Amsterdam Zuidas -Rai' 'The Fountain Loft - 170sqm'
#  'Oever House' 'Vondel 99' 'Amsterdam Hostel Uptown' 'Prinsenhotel'
#  'InterContinental Amstel Amsterdam, an IHG Hotel'
#  'Inntel Hotels Amsterdam Landmark'
#  'Banks Mansion - All Inclusive Boutique Hotel'
#  "art'otel amsterdam, Powered by Radisson Hotels"
#  'Amsterdam ID Aparthotel' 'Amistad hotel'
#  'Park Plaza Vondelpark Amsterdam' 'Hotel Fine Harmony' 'Canal House'
#  'B&B Expo House' 'Appartement vlakbij Antwerpen centrum!'
#  'The Greenplace Apartments in the Heart of Antwerp'
#  'Cauliflower Lodge. Apartment in Heart of Antwerp'
#  'HOFMARKGRAAF - Unique apartment in historic Antwerp mansion'
#  'Antwerp Center Cozy Cityflats' 'Casa di Cynthia'
#  'Boho Apartments - 2 Bedrooms'
#  'Classy flat with awesome view and great location!'
#  'Cosy studio in city center with sunny terrace, free NETFLIX and Wifi'
#  'Two-Bedroom Apartments in the Heart of Antwerp'
#  'Di-Ann City Centre Hotel' 'bken Aprt'
#  'Waanzinnige woning met tuin en parkeergelegenheid!'
#  'The Hendrik Square Apartments' 'Central Perk Apartments-Antwerp'
#  'Rustieke studio in hartje antwerpen' 'Balinese Cityflat AC'
#  'Cosy apartment Antwerpen center2' 'Bnb Antwerp SportPlaza'
#  'Light House Lodge. Apartment in Center of Antwerp'
#  'The Greenplace Lodge. Apartment in Heart of Antwerp.'
#  'The Hendrik Lodge Old Town Antwerp'
#  'SLEEP INN - Arizona flat with cityview'
#  'SLEEP INN - Black and White modern flat with cityview' 'Bkenkember Aprt'
#  'Marble Lodge Apartments in the Center of Antwerp'
#  'Apartment Light House. Heart of Antwerp'
#  'The Bright Stone Lodge. Heart of Antwerp' 'The Antwerp Marble Lodge'
#  'The Hendrik House in Old Town Antwerp'
#  'Large Antwerp City Center Apartments' 'Hotel Amsterdam De Roode Leeuw'
#  'Cafe Modern' 'City Wohnung Zentral 89-12'
#  'Office Apartment zentral zur Dortmunder Innenstadt'
#  'Clayton Hotel Amsterdam American' 'Amadi Panorama Hotel'
#  'Bob W Oosterpark' 'Jordaan Canal View Apartment' 'Pulitzer Amsterdam'
#  'Private studio in Antwerp' 'Foodiejive'
#  'Industriële WOW! Privé studio-40m2-Eigen ingang' 'Avenue Hotel'
#  'Maison ELLE Amsterdam' 'Amster Houseboat Bed without Breakfast'
#  'WestCord Art Hotel Amsterdam 4 stars' 'Casa di maksch de miniatura'
#  'The Manor Amsterdam' 'Turnhout City Hotel'
#  'Restaurant & Guesthouse Cachet de Cire' 'RS10 Turnhout'
#  "B&B Bon-Bon 'nuit'" 'Hotel Ter Driezen' 'Corsendonk Turnova'
#  'De Buitenmuur Guest House' 'B&B De Joker' 'B&B Ginnekenshoeve'
#  'B&B Biesvenhof' 'B&B Wepa-hof' 'De Gorzen' 'B&B Stillant'
#  "Biohoeve 't Bezige Bieke met privé wellness" 'B&B Domein Rodin'
#  'Kromven On Wheels' 'Colonie 7 - Gastenkamers'
#  'Vakantiepark Breebos: Empty Lots for tents and mobile homes'
#  'Bungalow aan de Visbeekvallei' 'AmberHuis' 'Guesthouse De Casteleer'
#  'B&B De Hertog van Baerle'
#  'Sfeervol landhuis met wellness in de groene Kempen' 'slapen bij alpacas'
#  'In de Wollekjes' 'Hotel Mansion' 'Dikker & Thijs Hotel' "Hetem's Room"
#  'Hotelboat Sarah' 'Hotel Atlas Vondelpark' 'Rosies Place'
#  'XO Hotels Blue Tower'
#  'Urban Condo - peacefull and cozy spot in historical center'
#  'Appartement met 2 slaapkamers en tuin in Amsterdam'
#  'foodiejive appartement 2' 'Luxueus Christmas appartement'
#  'Smartflats - Meir Antwerp' 'Hotel2Stay' 'Manu & Jilly Bnb'
#  'Apartment mit großem Balkon' 'ATW Apartments' "The Collector's House"
#  'Uitzicht op het MAS' 'Big Sunset 3 Bedroom House with a Garden' 'Coco'
#  'Hotel Alexander' 'Hotel van de Vijsel' 'Amsterdam Teleport Hotel'
#  'Ambassade Hotel' 'B&B Modern Times' 'Quentin Arrive Hotel'
#  'Hotel JL No76' 'Nova Apartments Amsterdam'
#  'Schöne 2 1/2 Zimmer Wohnung im Herzen von Dortmund'
#  'SWEETS - Kattenslootbrug' 'SWEETS - Hortusbrug' 'Hotel des Arts'
#  'B&B 1971 Hazenstraat - Shared Bathroom' 'Mi BnB Amsterdam'
#  'Amsterdam Canal Hotel' 'Quentin Zoo hotel' 'Coco’s place'
#  'The Card Room Green Studio'
#  'Nice 2 double Bed in sunny House in Amsterdam west'
#  'Sir Albert Hotel, part of Sircle Collection'
#  'Sir Adam Hotel, part of Sircle Collection'
#  'Rembrandtplein Bed & Breakfast' 'Top Of The City'
#  'Prachtig appartement met weids uitzicht op AAA locatie'
#  'Cosy renovated 1 bedroom apartment.' 'Jailhouse Rock Apartament'
#  'Corner appartament' 'London Tower Apartments - Antwerp'
#  'Dutch Design Hotel Vondelpark' 'Amsterdam Alley Apartment'
#  'Hotelboat Allure' 'The Central Square Residence'
#  'Apartment Pacific - Duplex with Sauna' 'Weber Hotel 117'
#  'Suite Aux Anges' 'Asile Flottant' 'Weber Hotel'
#  'Tempel Cathedral Lodge in the Heart of Antwerp'
#  'Eric Vökel Boutique Apartments - Riverfront Suites' 'Chasse Hotel'
#  'Quentin Golden Bear Hotel' 'Da Costa Suite' 'gouwzicht'
#  'Park View Apartment' 'Classy Room 17th C Canalhouse'
#  'Boutique Apartments Amsterdam' 'The Sixteen' 'Zuiderzin'
#  'Carriage House in quiet ecological garden'
#  'Charming & Spacious Antwerp City Center Apartments' 'Le Lambermont'
#  'Crane Hotel Faralda' 'The Meir Lodge. Apartments in heart of Antwerp'
#  'The Charming Hendrik Square Apartments' 'Saint Pauls Lodge'
#  'Apartment with Rooftop Terrace in the Heart of Antwerp'
#  'Lily Apartment. Historic Center of Antwerp'
#  'Antwerp Old Town Centrum Apartment'
#  'Spacious Apartments in the Heart of Antwerp' 'The National Lodge'
#  'City-centre, Canal-house, luxurious , stylish bedroom, ensuite bathroom, own entrance'
#  'Leidse Square 5 star Luxury Apartment'
#  'Ground Floor Apartment Westerpark' 'Hotel Amstelzicht'
#  'The Fashion Street Residence']
# location ['Amsterdam City Center, Amsterdam' 'Oud Zuid, Amsterdam'
#  'Oost, Amsterdam' 'Westpoort, Amsterdam' 'Oud West, Amsterdam'
#  'Amsterdam Noord, Amsterdam' 'Osdorp, Amsterdam'
#  'Geuzenveld-Slotermeer, Amsterdam' 'Zuidoost, Amsterdam'
#  'Zeeburg, Amsterdam' 'Sloterdijk, Amsterdam' 'Antwerp Center, Antwerp'
#  'Antwerp' 'Berchem, Antwerp' 'Dortmund City Centre, Dortmund' 'Dortmund'
#  'Zuideramstel, Amsterdam' 'Slotervaart, Amsterdam'
#  'Bijlmermeer, Amsterdam' 'Borgerhout, Antwerp' 'Amsterdam'
#  'Westerpark, Amsterdam' 'Bos en Lommer, Amsterdam' 'Deurne, Antwerp'
#  'Wilrijk, Antwerp' 'Hoboken, Antwerp' 'Merksem, Antwerp'
#  'De Baarsjes, Amsterdam' 'IJburg, Amsterdam' 'Turnhout' 'Beerse'
#  'Merksplas' 'Oud-Turnhout' 'Gierle' 'Rijkevorsel' 'Vlimmeren' 'Kasterlee'
#  'Baarle-Hertog']
# price ['MKD\xa014,351' 'MKD\xa08,890' 'MKD\xa05,267' ... 'MKD\xa049,158'
#  'MKD\xa048,788' 'MKD\xa09,048']
# date ["['2024-02-01', '2024-02-02']" "['2024-02-02', '2024-02-03']"
#  "['2024-02-03', '2024-02-04']" "['2024-02-04', '2024-02-05']"
#  "['2024-02-05', '2024-02-06']" "['2024-02-06', '2024-02-07']"
#  "['2024-02-07', '2024-02-08']" "['2024-02-08', '2024-02-09']"
#  "['2024-02-09', '2024-02-10']" "['2024-02-10', '2024-02-11']"
#  "['2024-02-11', '2024-02-12']" "['2024-02-12', '2024-02-13']"
#  "['2024-02-13', '2024-02-14']" "['2024-02-14', '2024-02-15']"
#  "['2024-02-15', '2024-02-16']" "['2024-02-16', '2024-02-17']"
#  "['2024-02-17', '2024-02-18']" "['2024-02-18', '2024-02-19']"
#  "['2024-02-19', '2024-02-20']" "['2024-02-20', '2024-02-21']"
#  "['2024-02-21', '2024-02-22']" "['2024-02-22', '2024-02-23']"
#  "['2024-02-23', '2024-02-24']" "['2024-02-24', '2024-02-25']"
#  "['2024-02-25', '2024-02-26']" "['2024-02-26', '2024-02-27']"
#  "['2024-02-27', '2024-02-28']" "['2024-02-28', '2024-02-29']"
#  "['2024-02-29', '2024-03-01']" "['2024-03-01', '2024-03-02']"
#  "['2024-03-02', '2024-03-03']" "['2024-03-03', '2024-03-04']"
#  "['2024-03-04', '2024-03-05']" "['2024-03-05', '2024-03-06']"
#  "['2024-03-06', '2024-03-07']" "['2024-03-07', '2024-03-08']"
#  "['2024-03-08', '2024-03-09']" "['2024-03-09', '2024-03-10']"
#  "['2024-03-10', '2024-03-11']" "['2024-03-11', '2024-03-12']"
#  "['2024-03-12', '2024-03-13']" "['2024-03-13', '2024-03-14']"
#  "['2024-03-14', '2024-03-15']" "['2024-03-15', '2024-03-16']"
#  "['2024-03-16', '2024-03-17']" "['2024-03-17', '2024-03-18']"
#  "['2024-03-18', '2024-03-19']" "['2024-03-19', '2024-03-20']"
#  "['2024-03-20', '2024-03-21']" "['2024-03-21', '2024-03-22']"
#  "['2024-03-22', '2024-03-23']" "['2024-03-23', '2024-03-24']"
#  "['2024-03-24', '2024-03-25']" "['2024-03-25', '2024-03-26']"
#  "['2024-03-26', '2024-03-27']" "['2024-03-27', '2024-03-28']"
#  "['2024-03-28', '2024-03-29']" "['2024-03-29', '2024-03-30']"
#  "['2024-03-30', '2024-03-31']" "['2024-03-31', '2024-04-01']"
#  "['2024-04-01', '2024-04-02']" "['2024-04-02', '2024-04-03']"
#  "['2024-04-03', '2024-04-04']" "['2024-04-04', '2024-04-05']"
#  "['2024-04-05', '2024-04-06']" "['2024-04-06', '2024-04-07']"
#  "['2024-04-07', '2024-04-08']" "['2024-04-08', '2024-04-09']"
#  "['2024-04-09', '2024-04-10']" "['2024-04-10', '2024-04-11']"
#  "['2024-04-11', '2024-04-12']" "['2024-04-12', '2024-04-13']"
#  "['2024-04-13', '2024-04-14']" "['2024-04-14', '2024-04-15']"
#  "['2024-04-15', '2024-04-16']" "['2024-04-16', '2024-04-17']"
#  "['2024-04-17', '2024-04-18']" "['2024-04-18', '2024-04-19']"
#  "['2024-04-19', '2024-04-20']" "['2024-04-20', '2024-04-21']"
#  "['2024-04-21', '2024-04-22']" "['2024-04-22', '2024-04-23']"
#  "['2024-04-23', '2024-04-24']" "['2024-04-24', '2024-04-25']"
#  "['2024-04-25', '2024-04-26']" "['2024-04-26', '2024-04-27']"
#  "['2024-04-27', '2024-04-28']" "['2024-04-28', '2024-04-29']"
#  "['2024-04-29', '2024-04-30']" "['2024-04-30', '2024-05-01']"
#  "['2024-05-01', '2024-05-02']" "['2024-05-02', '2024-05-03']"
#  "['2024-05-03', '2024-05-04']" "['2024-05-04', '2024-05-05']"
#  "['2024-05-05', '2024-05-06']" "['2024-05-06', '2024-05-07']"
#  "['2024-05-07', '2024-05-08']" "['2024-05-08', '2024-05-09']"
#  "['2024-05-09', '2024-05-10']" "['2024-05-10', '2024-05-11']"
#  "['2024-05-11', '2024-05-12']" "['2024-05-12', '2024-05-13']"
#  "['2024-05-13', '2024-05-14']" "['2024-05-14', '2024-05-15']"
#  "['2024-05-15', '2024-05-16']" "['2024-05-16', '2024-05-17']"
#  "['2024-05-17', '2024-05-18']" "['2024-05-18', '2024-05-19']"
#  "['2024-05-19', '2024-05-20']" "['2024-05-20', '2024-05-21']"
#  "['2024-05-21', '2024-05-22']" "['2024-05-22', '2024-05-23']"
#  "['2024-05-23', '2024-05-24']" "['2024-05-24', '2024-05-25']"
#  "['2024-05-25', '2024-05-26']" "['2024-05-26', '2024-05-27']"
#  "['2024-05-27', '2024-05-28']" "['2024-05-28', '2024-05-29']"
#  "['2024-05-29', '2024-05-30']" "['2024-05-30', '2024-05-31']"
#  "['2024-05-31', '2024-06-01']" "['2024-06-01', '2024-06-02']"
#  "['2024-06-02', '2024-06-03']" "['2024-06-03', '2024-06-04']"
#  "['2024-06-04', '2024-06-05']" "['2024-06-05', '2024-06-06']"
#  "['2024-06-06', '2024-06-07']" "['2024-06-07', '2024-06-08']"
#  "['2024-06-08', '2024-06-09']" "['2024-06-09', '2024-06-10']"
#  "['2024-06-10', '2024-06-11']" "['2024-06-11', '2024-06-12']"
#  "['2024-06-12', '2024-06-13']" "['2024-06-13', '2024-06-14']"
#  "['2024-06-14', '2024-06-15']" "['2024-06-15', '2024-06-16']"
#  "['2024-06-16', '2024-06-17']" "['2024-06-17', '2024-06-18']"
#  "['2024-06-18', '2024-06-19']" "['2024-06-19', '2024-06-20']"
#  "['2024-06-20', '2024-06-21']" "['2024-06-21', '2024-06-22']"
#  "['2024-06-22', '2024-06-23']" "['2024-06-23', '2024-06-24']"
#  "['2024-06-24', '2024-06-25']" "['2024-06-25', '2024-06-26']"
#  "['2024-06-26', '2024-06-27']" "['2024-06-27', '2024-06-28']"
#  "['2024-06-28', '2024-06-29']" "['2024-06-29', '2024-06-30']"
#  "['2024-06-30', '2024-07-01']" "['2024-07-01', '2024-07-02']"
#  "['2024-07-02', '2024-07-03']" "['2024-07-03', '2024-07-04']"
#  "['2024-07-04', '2024-07-05']" "['2024-07-05', '2024-07-06']"
#  "['2024-07-06', '2024-07-07']" "['2024-07-07', '2024-07-08']"
#  "['2024-07-08', '2024-07-09']" "['2024-07-09', '2024-07-10']"
#  "['2024-07-10', '2024-07-11']" "['2024-07-11', '2024-07-12']"
#  "['2024-07-12', '2024-07-13']" "['2024-07-13', '2024-07-14']"
#  "['2024-07-14', '2024-07-15']" "['2024-07-15', '2024-07-16']"
#  "['2024-07-16', '2024-07-17']" "['2024-07-17', '2024-07-18']"
#  "['2024-07-18', '2024-07-19']" "['2024-07-19', '2024-07-20']"
#  "['2024-07-20', '2024-07-21']" "['2024-07-21', '2024-07-22']"
#  "['2024-07-22', '2024-07-23']" "['2024-07-23', '2024-07-24']"
#  "['2024-07-24', '2024-07-25']" "['2024-07-25', '2024-07-26']"
#  "['2024-07-26', '2024-07-27']" "['2024-07-27', '2024-07-28']"
#  "['2024-07-28', '2024-07-29']" "['2024-07-29', '2024-07-30']"
#  "['2024-07-30', '2024-07-31']" "['2024-07-31', '2024-08-01']"
#  "['2024-08-01', '2024-08-02']" "['2024-08-02', '2024-08-03']"
#  "['2024-08-03', '2024-08-04']" "['2024-08-04', '2024-08-05']"
#  "['2024-08-05', '2024-08-06']" "['2024-08-06', '2024-08-07']"
#  "['2024-08-07', '2024-08-08']" "['2024-08-08', '2024-08-09']"
#  "['2024-08-09', '2024-08-10']" "['2024-08-10', '2024-08-11']"
#  "['2024-08-11', '2024-08-12']" "['2024-08-12', '2024-08-13']"
#  "['2024-08-13', '2024-08-14']" "['2024-08-14', '2024-08-15']"
#  "['2024-08-15', '2024-08-16']" "['2024-08-16', '2024-08-17']"
#  "['2024-08-17', '2024-08-18']" "['2024-08-18', '2024-08-19']"
#  "['2024-08-19', '2024-08-20']" "['2024-08-20', '2024-08-21']"
#  "['2024-08-21', '2024-08-22']" "['2024-08-22', '2024-08-23']"
#  "['2024-08-23', '2024-08-24']" "['2024-08-24', '2024-08-25']"
#  "['2024-08-25', '2024-08-26']" "['2024-08-26', '2024-08-27']"
#  "['2024-08-27', '2024-08-28']" "['2024-08-28', '2024-08-29']"
#  "['2024-08-29', '2024-08-30']" "['2024-08-30', '2024-08-31']"
#  "['2024-08-31', '2024-09-01']" "['2024-09-01', '2024-09-02']"
#  "['2024-09-02', '2024-09-03']" "['2024-09-03', '2024-09-04']"
#  "['2024-09-04', '2024-09-05']" "['2024-09-05', '2024-09-06']"
#  "['2024-09-06', '2024-09-07']" "['2024-09-07', '2024-09-08']"
#  "['2024-09-08', '2024-09-09']" "['2024-09-09', '2024-09-10']"
#  "['2024-09-10', '2024-09-11']" "['2024-09-11', '2024-09-12']"
#  "['2024-09-12', '2024-09-13']" "['2024-09-13', '2024-09-14']"
#  "['2024-09-14', '2024-09-15']" "['2024-09-15', '2024-09-16']"
#  "['2024-09-16', '2024-09-17']" "['2024-09-17', '2024-09-18']"
#  "['2024-09-18', '2024-09-19']" "['2024-09-19', '2024-09-20']"
#  "['2024-09-20', '2024-09-21']" "['2024-09-21', '2024-09-22']"
#  "['2024-09-22', '2024-09-23']" "['2024-09-23', '2024-09-24']"
#  "['2024-09-24', '2024-09-25']" "['2024-09-25', '2024-09-26']"
#  "['2024-09-26', '2024-09-27']" "['2024-09-27', '2024-09-28']"
#  "['2024-09-28', '2024-09-29']" "['2024-09-29', '2024-09-30']"
#  "['2024-09-30', '2024-10-01']" "['2024-10-01', '2024-10-02']"
#  "['2024-10-02', '2024-10-03']" "['2024-10-03', '2024-10-04']"
#  "['2024-10-04', '2024-10-05']" "['2024-10-05', '2024-10-06']"
#  "['2024-10-06', '2024-10-07']" "['2024-10-07', '2024-10-08']"
#  "['2024-10-08', '2024-10-09']" "['2024-10-09', '2024-10-10']"
#  "['2024-10-10', '2024-10-11']" "['2024-10-11', '2024-10-12']"
#  "['2024-10-12', '2024-10-13']" "['2024-10-13', '2024-10-14']"
#  "['2024-10-14', '2024-10-15']" "['2024-10-15', '2024-10-16']"
#  "['2024-10-16', '2024-10-17']" "['2024-10-17', '2024-10-18']"
#  "['2024-10-18', '2024-10-19']" "['2024-10-19', '2024-10-20']"
#  "['2024-10-20', '2024-10-21']" "['2024-10-21', '2024-10-22']"
#  "['2024-10-22', '2024-10-23']" "['2024-10-23', '2024-10-24']"
#  "['2024-10-24', '2024-10-25']" "['2024-10-25', '2024-10-26']"
#  "['2024-10-26', '2024-10-27']" "['2024-10-27', '2024-10-28']"
#  "['2024-10-28', '2024-10-29']" "['2024-10-29', '2024-10-30']"
#  "['2024-10-30', '2024-10-31']" "['2024-10-31', '2024-11-01']"
#  "['2024-11-01', '2024-11-02']" "['2024-11-02', '2024-11-03']"
#  "['2024-11-03', '2024-11-04']" "['2024-11-04', '2024-11-05']"
#  "['2024-11-05', '2024-11-06']" "['2024-11-06', '2024-11-07']"
#  "['2024-11-07', '2024-11-08']" "['2024-11-08', '2024-11-09']"
#  "['2024-11-09', '2024-11-10']" "['2024-11-10', '2024-11-11']"
#  "['2024-11-11', '2024-11-12']" "['2024-11-12', '2024-11-13']"
#  "['2024-11-13', '2024-11-14']" "['2024-11-14', '2024-11-15']"
#  "['2024-11-15', '2024-11-16']" "['2024-11-16', '2024-11-17']"
#  "['2024-11-17', '2024-11-18']" "['2024-11-18', '2024-11-19']"
#  "['2024-11-19', '2024-11-20']" "['2024-11-20', '2024-11-21']"
#  "['2024-11-21', '2024-11-22']" "['2024-11-22', '2024-11-23']"
#  "['2024-11-23', '2024-11-24']" "['2024-11-24', '2024-11-25']"
#  "['2024-11-25', '2024-11-26']" "['2024-11-26', '2024-11-27']"
#  "['2024-11-27', '2024-11-28']" "['2024-11-28', '2024-11-29']"
#  "['2024-11-29', '2024-11-30']" "['2024-11-30', '2024-12-01']"
#  "['2024-12-01', '2024-12-02']" "['2024-12-02', '2024-12-03']"
#  "['2024-12-03', '2024-12-04']" "['2024-12-04', '2024-12-05']"
#  "['2024-12-05', '2024-12-06']" "['2024-12-06', '2024-12-07']"
#  "['2024-12-07', '2024-12-08']" "['2024-12-08', '2024-12-09']"
#  "['2024-12-09', '2024-12-10']" "['2024-12-10', '2024-12-11']"
#  "['2024-12-11', '2024-12-12']" "['2024-12-12', '2024-12-13']"
#  "['2024-12-13', '2024-12-14']" "['2024-12-14', '2024-12-15']"
#  "['2024-12-15', '2024-12-16']" "['2024-12-16', '2024-12-17']"
#  "['2024-12-17', '2024-12-18']" "['2024-12-18', '2024-12-19']"
#  "['2024-12-19', '2024-12-20']" "['2024-12-20', '2024-12-21']"
#  "['2024-12-21', '2024-12-22']" "['2024-12-22', '2024-12-23']"
#  "['2024-12-23', '2024-12-24']" "['2024-12-24', '2024-12-25']"
#  "['2024-12-25', '2024-12-26']" "['2024-12-26', '2024-12-27']"
#  "['2024-12-27', '2024-12-28']" "['2024-12-28', '2024-12-29']"
#  "['2024-12-29', '2024-12-30']" "['2024-12-30', '2024-12-31']"
#  "['2024-12-31', '2025-01-01']" "['2025-01-01', '2025-01-02']"
#  "['2025-01-02', '2025-01-03']" "['2025-01-03', '2025-01-04']"
#  "['2025-01-04', '2025-01-05']" "['2025-01-05', '2025-01-06']"
#  "['2025-01-06', '2025-01-07']" "['2025-01-07', '2025-01-08']"
#  "['2025-01-08', '2025-01-09']" "['2025-01-09', '2025-01-10']"
#  "['2025-01-10', '2025-01-11']" "['2025-01-11', '2025-01-12']"
#  "['2025-01-12', '2025-01-13']" "['2025-01-13', '2025-01-14']"
#  "['2025-01-14', '2025-01-15']" "['2025-01-15', '2025-01-16']"
#  "['2025-01-16', '2025-01-17']" "['2025-01-17', '2025-01-18']"
#  "['2025-01-18', '2025-01-19']" "['2025-01-19', '2025-01-20']"
#  "['2025-01-20', '2025-01-21']" "['2025-01-21', '2025-01-22']"
#  "['2025-01-22', '2025-01-23']" "['2025-01-23', '2025-01-24']"
#  "['2025-01-24', '2025-01-25']" "['2025-01-25', '2025-01-26']"
#  "['2025-01-26', '2025-01-27']" "['2025-01-27', '2025-01-28']"
#  "['2025-01-28', '2025-01-29']" "['2025-01-29', '2025-01-30']"
#  "['2025-01-30', '2025-01-31']" "['2025-01-31', '2025-02-01']"]
# stars [ 4. nan  2.  3.  1.  5.]
# distance_from_center ['0.6 km from center' '1.7 km from center' '4.2 km from center'
#  '1.2 km from center' '2.1 km from center' '1.3 km from center'
#  '3.3 km from center' '2.6 km from center' '2.3 km from center'
#  '2.2 km from center' '1.6 km from center' '350 m from center'
#  '1.8 km from center' '3 km from center' '8.4 km from center'
#  '1.9 km from center' '3.1 km from center' '1.5 km from center'
#  '2 km from center' '3.8 km from center' '400 m from center'
#  '4.3 km from center' '3.9 km from center' '7.6 km from center'
#  '2.8 km from center' '8.6 km from center' '8.5 km from center'
#  '3.4 km from center' '1.1 km from center' '150 m from center'
#  '0.5 km from center' '1.4 km from center' '3.5 km from center'
#  '500 m from center' '0.8 km from center' '50 m from center'
#  '300 m from center' '30.6 km from center' '1 km from center'
#  '200 m from center' '450 m from center' '0.7 km from center'
#  '3.7 km from center' '10.1 km from center' '0.9 km from center'
#  '10 km from center' '4.6 km from center' '5.1 km from center'
#  '250 m from center' '4.5 km from center' '7.4 km from center'
#  '7.8 km from center' '2.7 km from center' '6.5 km from center'
#  '4.4 km from center' '6.6 km from center' '4.8 km from center'
#  '5.5 km from center' '7.2 km from center' '3.6 km from center'
#  '4.1 km from center' '2.4 km from center' '2.5 km from center'
#  '5.2 km from center' '100 m from center' '7.3 km from center'
#  '6.9 km from center' '7.9 km from center' '5 km from center'
#  '9.9 km from center' '10.2 km from center' '2.9 km from center'
#  '7.5 km from center' '6.8 km from center' '4 km from center'
#  '6.2 km from center' '6.7 km from center' '9.3 km from center'
#  '6 km from center' '7.7 km from center' '9.4 km from center'
#  '4.7 km from center' '3.2 km from center' '4.9 km from center'
#  '5.8 km from center' '5.9 km from center' '5.7 km from center'
#  '5.4 km from center' '5.6 km from center' '6.4 km from center'
#  '6.1 km from center' '8.2 km from center' '10.3 km from center'
#  '10.9 km from center' '1 km from map center' '1.1 km from map center'
#  '1.2 km from map center' '1.3 km from map center'
#  '1.4 km from map center' '1.6 km from map center'
#  '1.9 km from map center' '1.7 km from map center'
#  '2.3 km from map center' '3.8 km from map center'
#  '5.9 km from map center' '6.3 km from map center' '7 km from map center'
#  '7.1 km from map center' '7.5 km from map center'
#  '7.9 km from map center' '8.1 km from map center'
#  '8.7 km from map center' '8.8 km from map center'
#  '9.3 km from map center' '10 km from map center'
#  '10.1 km from map center' '10.6 km from map center' '8.8 km from center'
#  '7 km from center']
# num_external_reviews ['1,044 reviews' '3,190 reviews' '1,155 reviews' '1,820 reviews'
#  '2,205 reviews' '2,482 reviews' '1,244 reviews' '2,171 reviews'
#  '3,177 reviews' '1,811 reviews' '1,904 reviews' '5,032 reviews'
#  '5,072 reviews' '2,218 reviews' '1,852 reviews' '1,359 reviews'
#  '3,594 reviews' '1,751 reviews' '1,778 reviews' '5,412 reviews'
#  '712 reviews' '333 reviews' '76 reviews' '2,340 reviews' '3,240 reviews'
#  '2,717 reviews' '1,825 reviews' '13,602 reviews' '1,028 reviews'
#  '2,278 reviews' '2,481 reviews' '4,597 reviews' '2,175 reviews'
#  '5,548 reviews' '1,701 reviews' '17,978 reviews' '10,971 reviews'
#  '3,005 reviews' '1,160 reviews' '8,022 reviews' '4,604 reviews'
#  '12,972 reviews' '7,331 reviews' '1,569 reviews' '9,119 reviews'
#  '2,933 reviews' '520 reviews' '12,332 reviews' '87 reviews'
#  '9,631 reviews' '6,256 reviews' '3,495 reviews' '8,798 reviews'
#  '2,821 reviews' '262 reviews' '9,411 reviews' '5,648 reviews'
#  '2,121 reviews' '1,303 reviews' '3,285 reviews' '4,220 reviews'
#  '1,442 reviews' '3,622 reviews' '1,977 reviews' '720 reviews'
#  '1,250 reviews' '3,111 reviews' '4,689 reviews' '4,072 reviews'
#  '1,534 reviews' '7,318 reviews' '1,839 reviews' '205 reviews'
#  '1,079 reviews' '3,954 reviews' '65 reviews' '660 reviews'
#  '1,141 reviews' '369 reviews' '2,656 reviews' '1,610 reviews'
#  '4,343 reviews' '34 reviews' '6,718 reviews' '439 reviews'
#  '3,026 reviews' '64 reviews' '548 reviews' '1,054 reviews'
#  '3,925 reviews' '4,057 reviews' '676 reviews' '3,768 reviews'
#  '2,952 reviews' '2,995 reviews' '911 reviews' '2,472 reviews'
#  '1,373 reviews' '209 reviews' '831 reviews' '783 reviews' '5,428 reviews'
#  '3,286 reviews' '1,765 reviews' '2,693 reviews' '1,275 reviews'
#  '2,063 reviews' '496 reviews' '894 reviews' '1,358 reviews'
#  '2,706 reviews' '4,513 reviews' '2,737 reviews' '62 reviews'
#  '312 reviews' '1,461 reviews' '1,039 reviews' '290 reviews'
#  '1,086 reviews' '1,611 reviews' '124 reviews' '1,636 reviews'
#  '1,619 reviews' '308 reviews' '769 reviews' '11 external reviews'
#  '563 reviews' '1,696 reviews' '392 reviews' '112 reviews' '1,274 reviews'
#  '14,790 reviews' '1,365 reviews' '9,128 reviews' '2,266 reviews'
#  '9,293 reviews' '15,520 reviews' '2,345 reviews' '607 reviews'
#  '1,549 reviews' '9,860 reviews' '3,995 reviews' '7,017 reviews'
#  '3,445 reviews' '2,639 reviews' '856 reviews' '9,822 reviews'
#  '1,436 reviews' '3,371 reviews' '3,048 reviews' '2,158 reviews'
#  '3,806 reviews' '7,537 reviews' '7,123 reviews' '4,391 reviews'
#  '5,357 reviews' '7,653 reviews' '1,046 reviews' '9,440 reviews'
#  '12,553 reviews' '3,789 reviews' '3,621 reviews' '1,037 reviews'
#  '4,284 reviews' '110 reviews' '517 reviews' '3,827 reviews'
#  '3,903 reviews' '1,930 reviews' '5,060 reviews' '698 reviews'
#  '2,917 reviews' '1 review' '3,102 reviews' '108 reviews' '1,240 reviews'
#  '1,882 reviews' '1,084 reviews' '407 reviews' '2,220 reviews'
#  '348 reviews' '35 reviews' '3,738 reviews' '1,222 reviews'
#  '1,670 reviews' '196 reviews' '98 reviews' '72 reviews' '173 reviews'
#  '483 reviews' '280 reviews' '451 reviews' '27 external reviews'
#  '8 reviews' '5,442 reviews' '1,318 reviews' '2,647 reviews'
#  '3,718 reviews' '8,448 reviews' '2,419 reviews' '1,293 reviews'
#  '2,254 reviews' '2,423 reviews' '7,970 reviews' '6,123 reviews'
#  '1,024 reviews' '625 reviews' '2,373 reviews' '2,904 reviews'
#  '2,902 reviews' '957 reviews' '2,535 reviews' '605 reviews'
#  '1,041 reviews' '1,255 reviews' '113 reviews' nan '1,209 reviews'
#  '38 reviews' '460 reviews' '814 reviews' '1,502 reviews' '7,513 reviews'
#  '944 reviews' '2,833 reviews' '965 reviews' '2,776 reviews'
#  '1,309 reviews' '73 reviews' '398 reviews' '492 reviews' '276 reviews'
#  '70 reviews' '2,292 reviews' '1,427 reviews' '2,879 reviews'
#  '2,953 reviews' '4,632 reviews' '1,835 reviews' '2,526 reviews'
#  '975 reviews' '2,420 reviews' '6,466 reviews' '1,598 reviews'
#  '3,847 reviews' '4,661 reviews' '1,001 reviews' '665 reviews'
#  '1,705 reviews' '4,406 reviews' '3,551 reviews' '159 reviews'
#  '166 reviews' '216 reviews' '1,739 reviews' '606 reviews' '1,273 reviews'
#  '9 reviews' '202 reviews' '3,891 reviews' '1,010 reviews' '6,798 reviews'
#  '8,237 reviews' '1,140 reviews' '810 reviews' '3,682 reviews'
#  '3,634 reviews' '2,796 reviews' '395 reviews' '3,000 reviews'
#  '516 reviews' '539 reviews' '1,759 reviews' '338 reviews' '1,069 reviews'
#  '5,184 reviews' '1,906 reviews' '2,860 reviews' '755 reviews'
#  '1,478 reviews' '1,707 reviews' '1,683 reviews' '376 reviews'
#  '481 reviews' '143 reviews' '880 reviews' '26 reviews' '318 reviews'
#  '45 reviews' '950 reviews' '1,439 reviews' '17 reviews' '2,025 reviews'
#  '1,648 reviews' '3,146 reviews' '2,722 reviews' '2,208 reviews'
#  '2,004 reviews' '3,604 reviews' '1,770 reviews' '37 reviews'
#  '6,212 reviews' '917 reviews' '2,903 reviews' '1,150 reviews'
#  '8,893 reviews' '1,347 reviews' '2,781 reviews' '1,940 reviews'
#  '5,299 reviews' '3,347 reviews' '2,830 reviews' '6,633 reviews'
#  '2,424 reviews' '443 reviews' '164 reviews' '1,933 reviews' '449 reviews'
#  '851 reviews' '28 reviews' '24 reviews' '15 reviews' '1,994 reviews'
#  '181 reviews' '3,307 reviews' '3,520 reviews' '2,133 reviews'
#  '8,525 reviews' '1,501 reviews' '4,745 reviews' '1,219 reviews'
#  '2,644 reviews' '2,551 reviews' '502 reviews' '117 reviews'
#  '1,221 reviews' '1,166 reviews' '881 reviews' '1,321 reviews'
#  '1,116 reviews' '1,399 reviews' '20 reviews' '3,003 reviews'
#  '816 reviews' '921 reviews' '131 reviews' '342 reviews' '129 reviews'
#  '2 reviews' '707 reviews' '35 external reviews' '524 reviews'
#  '59 reviews' '13 reviews' '58 reviews' '571 reviews' '5 reviews'
#  '11 reviews' '1,507 reviews' '3,658 reviews' '1,105 reviews'
#  '1,121 reviews' '1,188 reviews' '8,744 reviews' '1,192 reviews'
#  '2,632 reviews' '1,634 reviews' '366 reviews' '4 reviews' '3,929 reviews'
#  '116 reviews' '2,469 reviews' '8,631 reviews' '1,555 reviews'
#  '6,388 reviews' '1,289 reviews' '2,555 reviews' '614 reviews'
#  '454 reviews' '2,428 reviews' '2,813 reviews' '311 reviews' '269 reviews'
#  '3,152 reviews' '2,626 reviews' '575 reviews' '1,310 reviews'
#  '48 reviews' '287 reviews' '1,067 reviews' '2,542 reviews' '579 reviews'
#  '979 reviews' '414 reviews' '372 reviews' '939 reviews' '3,103 reviews'
#  '1,390 reviews' '637 reviews' '44 external reviews' '581 reviews'
#  '106 reviews' '250 reviews' '66 reviews' '55 reviews' '2,349 reviews'
#  '3,642 reviews' '1,026 reviews' '544 reviews' '1,721 reviews'
#  '1,952 reviews' '1,038 reviews' '1,970 reviews' '3,727 reviews'
#  '2,947 reviews' '4,138 reviews' '1,406 reviews' '962 reviews'
#  '68 reviews' '664 reviews' '795 reviews' '8,244 reviews' '3,848 reviews'
#  '896 reviews' '612 reviews' '378 reviews' '626 reviews' '63 reviews'
#  '1,603 reviews' '1,950 reviews' '88 reviews' '19 reviews' '80 reviews'
#  '138 reviews' '251 reviews' '560 reviews' '51 reviews' '6,480 reviews'
#  '3,108 reviews' '1,851 reviews' '244 reviews' '97 reviews'
#  '4,454 reviews' '5,628 reviews' '913 reviews' '151 reviews' '21 reviews'
#  '81 reviews' '688 reviews' '33 reviews' '1,545 reviews' '3,098 reviews'
#  '99 reviews' '94 reviews' '464 reviews' '17 external reviews'
#  '239 reviews' '102 reviews' '827 reviews' '2,622 reviews' '49 reviews'
#  '757 reviews' '1,323 reviews' '3 reviews' '3,461 reviews' '557 reviews'
#  '432 reviews' '105 reviews' '57 reviews' '3,131 reviews' '359 reviews'
#  '3,474 reviews' '3,069 reviews' '5,179 reviews' '1,238 reviews'
#  '416 reviews' '430 reviews' '283 reviews' '1,795 reviews' '1,108 reviews'
#  '3,134 reviews' '5,809 reviews' '677 reviews' '43 reviews' '78 reviews'
#  '1,055 reviews' '2,143 reviews' '1,270 reviews' '1,324 reviews'
#  '107 reviews' '1,560 reviews' '168 reviews' '961 reviews' '10 reviews'
#  '1,409 reviews' '2,927 reviews' '4,022 reviews' '1,030 reviews'
#  '1,190 reviews' '2,660 reviews' '30 external reviews' '5,900 reviews'
#  '3,259 reviews' '230 reviews' '357 reviews' '2,109 reviews'
#  '5,456 reviews' '3,378 reviews' '5,143 reviews' '860 reviews'
#  '1,860 reviews' '1,195 reviews' '711 reviews' '1,900 reviews'
#  '334 reviews' '5,514 reviews' '4,331 reviews' '3,726 reviews'
#  '6,577 reviews' '291 reviews' '3,455 reviews' '405 reviews' '25 reviews'
#  '240 reviews' '2,983 reviews' '493 reviews' '1,605 reviews'
#  '1,118 reviews' '3,077 reviews' '3,322 reviews' '84 reviews'
#  '5,534 reviews' '365 reviews' '6,209 reviews' '766 reviews'
#  '1,641 reviews' '1,261 reviews' '198 reviews' '89 reviews'
#  '1,465 reviews' '161 reviews' '2,928 reviews' '30 reviews'
#  '6,723 reviews' '136 reviews' '284 reviews' '362 reviews' '1,445 reviews'
#  '3,194 reviews' '1,582 reviews' '1,457 reviews' '6 reviews' '179 reviews'
#  '1,547 reviews' '1,093 reviews' '325 reviews' '231 reviews' '992 reviews'
#  '10,171 reviews' '177 reviews' '74 reviews' '22 reviews' '877 reviews'
#  '329 reviews' '60 reviews' '584 reviews' '364 reviews' '343 reviews'
#  '525 reviews' '1,526 reviews' '2,157 reviews' '7,551 reviews'
#  '153 reviews' '4,473 reviews' '1,259 reviews' '4,860 reviews'
#  '212 reviews' '246 reviews' '71 reviews' '358 reviews' '7 reviews'
#  '1,405 reviews' '23 reviews' '304 reviews' '242 reviews' '139 reviews'
#  '430 external reviews' '3 external reviews' '195 reviews'
#  '9 external reviews' '57 external reviews' '174 reviews' '42 reviews'
#  '16 reviews' '111 reviews' '4,360 reviews' '572 reviews' '2,229 reviews'
#  '296 reviews' '11,398 reviews' '2,321 reviews' '1,553 reviews'
#  '786 reviews' '3,160 reviews' '580 reviews' '252 reviews' '18 reviews'
#  '12 external reviews' '29 reviews' '2,203 reviews' '69 reviews'
#  '12 reviews' '185 reviews' '213 reviews' '114 reviews' '360 reviews'
#  '264 reviews' '133 reviews' '2,873 reviews' '420 reviews' '46 reviews'
#  '3,224 reviews' '4,609 reviews' '192 reviews' '1,088 reviews'
#  '14 reviews' '4,390 reviews' '991 reviews' '126 reviews' '773 reviews'
#  '2,299 reviews' '742 reviews' '299 reviews' '695 reviews' '53 reviews'
#  '672 reviews' '268 reviews' '233 reviews' '347 reviews' '409 reviews'
#  '215 reviews' '1,536 reviews' '1,944 reviews' '2,075 reviews'
#  '9,823 reviews' '10,974 reviews' '678 reviews' '3,325 reviews'
#  '433 reviews' '1,772 reviews' '93 reviews' '5,063 reviews'
#  '6,473 reviews' '713 reviews' '12,557 reviews' '3,548 reviews'
#  '7,539 reviews' '148 reviews' '219 reviews' '77 reviews' '1,723 reviews'
#  '2,678 reviews' '7,554 reviews' '983 reviews' '346 reviews' '923 reviews'
#  '1,694 reviews' '178 reviews' '14,793 reviews' '6,124 reviews'
#  '235 reviews' '1,753 reviews' '2,256 reviews' '6,258 reviews'
#  '1,516 reviews' '271 reviews' '31 reviews' '12,337 reviews'
#  '2,834 reviews' '386 external reviews' '504 reviews' '3,227 reviews'
#  '1,381 reviews' '232 reviews' '394 reviews' '220 reviews' '327 reviews'
#  '145 reviews' '377 reviews' '286 reviews' '546 reviews' '130 reviews'
#  '662 reviews' '1,766 reviews' '724 reviews' '83 reviews' '40 reviews'
#  '294 reviews' '1,548 reviews' '103 reviews' '1,340 reviews' '75 reviews']
# booking_user_ratings ['Excellent' 'Good' 'Very Good' 'Review score' 'Wonderful' 'Excellent 8.7'
#  'Wonderful 9.1' nan 'Exceptional' 'Exceptional 9.6' 'Wonderful 9.2'
#  'Wonderful 9.3' 'Excellent 8.9' 'Very Good 8.3']
# avg_user_ratings [ 8.9  7.5  8.3  7.1  7.3  7.2  6.7  6.3  7.4  6.8  7.8  7.7  8.1  6.1
#   8.   5.9  7.9  6.9  8.4  7.6  7.   8.2  8.6  8.5  8.7  8.8  9.3  9.4
#   5.8  nan  5.6  9.   5.3  4.6  4.7  6.5  6.6  9.1  5.2  6.2  9.8  6.
#   5.4  5.7  5.5  9.2  4.5  4.9  4.8 10.   9.5  6.4  9.7  9.6  2.   9.9
#   5.   3.   3.8  4.4  3.3  3.7  1. ]
# airport_taxi ['Limited-time Deal' 'No airport taxi' 'Early 2024 Deal'
#  'Free airport taxi']
# travel_sustainable_level ['Travel Sustainable Level 3+' nan 'Travel Sustainable Level 3'
#  'Travel Sustainable Level 1' 'Travel Sustainable Level 2']
# has_free_cancelation [False  True]
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# name                            0
# location                        0
# price                           0
# date                            0
# stars                       22224
# distance_from_center            0
# num_external_reviews          528
# booking_user_ratings          528
# avg_user_ratings             1088
# airport_taxi                    0
# travel_sustainable_level    13789
# has_free_cancelation            0
# dtype: int64

# %% [markdown]
# Above we can see all the unique values. We can conclude that
#
# 1. the **price** should be converted into Euros and MKD prefix should be removed from the entries.
# 2. **stars** column contains Nan values (at least 1), so we should replace them with 0. This would only make sense since nan would represent no stars present, i.e. 0 stars.
# 3. **distance from center** is represented in string format. We can rename the column and represent the entries in int values, i.e. km from center.
# 4. **number of external reviews** contains a colon mark and 'reviews' suffix which should both be removed and the column represented as an int column
# 5. **booking user ratings** also contains dirty data. Nan, "Review score" and user ratings that were incorectly parsed when scraping. These will be converted to numerical values with the help of a dictinary mapping.
# 6. **airport taxi** contains values that we are not interested in, we will remove these and mark them as Nan.
# 7. we will also map the **travel sustainable level** column into int values.
# 8. **avg_user_ratings** is a column of user ratings from (1-10), we can clean this up by applying the average user rating of all the hotels residing in the given area/town.
# 9. **airport_taxi** is a column defining wether the hotel/appartment has an airport taxi available, we should consider Nan the same as "No airport taxi".
# 10. **date** column contains a list of 2 dates - arriving and departure dates, we really only need the first date, i.e. the date of stay.

# %% [markdown]
# ## Clean up the data

# %% [markdown]
# #### 1. the **price** should be converted into Euros and MKD prefix should be removed from the entries

# %%
mkd_to_euro_coef = 0.01626717
df["price"] = df["price"].str.replace(r'[MKD,]', '', regex=True).str.strip().astype(int) * mkd_to_euro_coef

# %%
df['price']
# Out:
# 0        233.450157
# 1        144.615141
# 2         85.679184
# 3         30.061730
# 4         50.102884
#             ...
# 54909    190.748835
# 54910    119.254623
# 54911    190.390958
# 54912     84.768223
# 54913    215.865346
# Name: price, Length: 54914, dtype: float64

# %% [markdown]
# #### 2. **stars** column contains Nan values (at least 1), so we should replace them with 0. This would only make sense since nan would represent no stars present, i.e. 0 stars.

# %%
df['stars'].fillna(0,inplace=True)
df['stars'] = df['stars'].astype(int)
df['stars'].unique()
# Out:
# array([4, 0, 2, 3, 1, 5])

# %% [markdown]
# #### 3. **distance from center** is represented in string format. We can rename the column and represent the entries in int values, i.e. km from center.

# %%
df["distance_from_center"] = df["distance_from_center"].str.extract("([\d.]+)",expand=False).astype(float)
df = df.rename({"distance_from_center": "km_from_center"}, axis="columns")
df["km_from_center"]
# Out:
# 0         0.6
# 1         1.7
# 2         4.2
# 3         1.2
# 4         2.1
#          ...
# 54909     0.6
# 54910    10.9
# 54911     3.0
# 54912     5.0
# 54913     1.1
# Name: km_from_center, Length: 54914, dtype: float64

# %% [markdown]
# #### 4. **number of external reviews** contains a colon mark and 'reviews' suffix which should both be removed and the column represented as an int column

# %%
df['num_external_reviews'] = pd.to_numeric(df['num_external_reviews'].str.replace('[^\d]+', '', regex=True), errors='coerce')

# %%
df['num_external_reviews'] = df['num_external_reviews'].fillna(0).astype(int)
df["num_external_reviews"]
# Out:
# 0        1044
# 1        3190
# 2        1155
# 3        1820
# 4        2205
#          ...
# 54909      11
# 54910      16
# 54911       3
# 54912       0
# 54913       0
# Name: num_external_reviews, Length: 54914, dtype: int64

# %% [markdown]
# #### 5. **booking user ratings** also contains dirty data. Nan, "Review score" and user ratings that were incorectly parsed when scraping. These will be converted to numerical values with the help of a dictinary mapping.
#
# We will count Review score as a lack of rating and map it the same value as Nan.

# %%
import numpy as np
df['booking_user_ratings']= df['booking_user_ratings'].str.extract('([^\d]+)', expand=False).str.strip()
df['booking_user_ratings'] = df['booking_user_ratings'].replace('Review score', np.nan )
df['booking_user_ratings'].unique()
# Out:
# array(['Excellent', 'Good', 'Very Good', nan, 'Wonderful', 'Exceptional'],
#       dtype=object)

# %%
ratings_mapping = {'Good': 1, 'Very Good': 2, 'Wonderful': 3, 'Exceptional': 4,'Excellent': 5, np.nan: 0}
df['booking_user_ratings'] = df['booking_user_ratings'].map(ratings_mapping)

# %%
df['booking_user_ratings'].unique()
# Out:
# array([5, 1, 2, 0, 3, 4])

# %% [markdown]
# #### 6. **airport taxi** contains values that we are not interested in, we will replace these and mark them as Nan.

# %%
df['airport_taxi'] = df['airport_taxi'].replace(['Limited-time Deal', 'Early 2024 Deal'], np.nan)
df['airport_taxi'].unique()
# Out:
# array([nan, 'No airport taxi', 'Free airport taxi'], dtype=object)

# %% [markdown]
# #### 7. we will also map the **travel sustainable level** column into int values.

# %%
level_mapping = {
    'Travel Sustainable Level 1': 1,
    'Travel Sustainable Level 2': 2,
    'Travel Sustainable Level 3': 3,
    'Travel Sustainable Level 3+': 4
}
df['travel_sustainable_level'] = df['travel_sustainable_level'].map(level_mapping).fillna(0).astype(int)
df["travel_sustainable_level"].unique()
# Out:
# array([4, 0, 3, 1, 2])

# %% [markdown]
# #### 8. handle **avg_user_ratings**. In certain instances, some locations have been designated with the title of their Municipality rather than using the name of the encompassing city to refer to that specific area. We will map these municipalities into the correct cities.

# %%
df['location'].unique()
# Out:
# array(['Amsterdam City Center, Amsterdam', 'Oud Zuid, Amsterdam',
#        'Oost, Amsterdam', 'Westpoort, Amsterdam', 'Oud West, Amsterdam',
#        'Amsterdam Noord, Amsterdam', 'Osdorp, Amsterdam',
#        'Geuzenveld-Slotermeer, Amsterdam', 'Zuidoost, Amsterdam',
#        'Zeeburg, Amsterdam', 'Sloterdijk, Amsterdam',
#        'Antwerp Center, Antwerp', 'Antwerp', 'Berchem, Antwerp',
#        'Dortmund City Centre, Dortmund', 'Dortmund',
#        'Zuideramstel, Amsterdam', 'Slotervaart, Amsterdam',
#        'Bijlmermeer, Amsterdam', 'Borgerhout, Antwerp', 'Amsterdam',
#        'Westerpark, Amsterdam', 'Bos en Lommer, Amsterdam',
#        'Deurne, Antwerp', 'Wilrijk, Antwerp', 'Hoboken, Antwerp',
#        'Merksem, Antwerp', 'De Baarsjes, Amsterdam', 'IJburg, Amsterdam',
#        'Turnhout', 'Beerse', 'Merksplas', 'Oud-Turnhout', 'Gierle',
#        'Rijkevorsel', 'Vlimmeren', 'Kasterlee', 'Baarle-Hertog'],
#       dtype=object)

# %%
df['town_location'] = df['location'].str.split().str[-1]
df['town_location'].unique()
# Out:
# array(['Amsterdam', 'Antwerp', 'Dortmund', 'Turnhout', 'Beerse',
#        'Merksplas', 'Oud-Turnhout', 'Gierle', 'Rijkevorsel', 'Vlimmeren',
#        'Kasterlee', 'Baarle-Hertog'], dtype=object)

# %%
municipality_to_city_map = {
    'Turnhout': 'Antwerp',
    'Beerse': 'Antwerp',
    'Merksplas': 'Antwerp',
    'Oud-Turnhout': 'Antwerp',
    'Gierle': 'Antwerp',
    'Rijkevorsel': 'Antwerp',
    'Vlimmeren': 'Antwerp',
    'Kasterlee': 'Antwerp',
    'Baarle-Hertog': 'Antwerp'
}

# %%
df['town_location'] = df['town_location'].replace(municipality_to_city_map)

df_mean_rating_by_town = df.groupby(df['town_location'].str.split().str[-1])['avg_user_ratings'].transform('mean')
df['avg_user_ratings'] = df['avg_user_ratings'].fillna(df_mean_rating_by_town)
df['town_location'].unique()
# Out:
# array(['Amsterdam', 'Antwerp', 'Dortmund'], dtype=object)

# %% [markdown]
# #### 9. handle **airport_taxi**

# %%
df[['airport_taxi']] = df[['airport_taxi']].fillna('No airport taxi') 
df['airport_taxi'] = df['airport_taxi'].map({'Free airport taxi': 1, 'No airport taxi': 0})

# %% [markdown]
# #### 10. clean up **date** column so that only 1 date (date of stay) is present

# %%
import ast
df['date'] = df['date'].apply(ast.literal_eval)
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x[0]))

# %% [markdown]
# ### Now we can finaly see our work... and how far we've come

# %%
nan_rows = df[df.isnull().any(axis=1)]
nan_rows
# Out:
# Empty DataFrame
# Columns: [name, location, price, date, stars, km_from_center, num_external_reviews, booking_user_ratings, avg_user_ratings, airport_taxi, travel_sustainable_level, has_free_cancelation, town_location]
# Index: []

# %% [markdown]
# ### The current state of our DF

# %%
df
# Out:
#                                                     name  \
# 0                     The Pavilions Amsterdam, The Toren
# 1                                      Sonder Park House
# 2                   Hotel Jansen Amsterdam Bajeskwartier
# 3                                               AmicitiA
# 4                                       Hotel Washington
# ...                                                  ...
# 54909  Schöne 2 1/2 Zimmer Wohnung im Herzen von Dort...
# 54910                                        schlafgut24
# 54911                       3 Zimmer Wohnung in Dortmund
# 54912                           Wohnung Nähe Uni,Stadion
# 54913                                          FeWo Born
#
#                                location       price       date  stars  \
# 0      Amsterdam City Center, Amsterdam  233.450157 2024-02-01      4
# 1                   Oud Zuid, Amsterdam  144.615141 2024-02-01      4
# 2                       Oost, Amsterdam   85.679184 2024-02-01      0
# 3      Amsterdam City Center, Amsterdam   30.061730 2024-02-01      0
# 4                   Oud Zuid, Amsterdam   50.102884 2024-02-01      2
# ...                                 ...         ...        ...    ...
# 54909    Dortmund City Centre, Dortmund  190.748835 2025-01-31      0
# 54910                          Dortmund  119.254623 2025-01-31      0
# 54911                          Dortmund  190.390958 2025-01-31      0
# 54912                          Dortmund   84.768223 2025-01-31      0
# 54913                          Dortmund  215.865346 2025-01-31      0
#
#        km_from_center  num_external_reviews  booking_user_ratings  \
# 0                 0.6                  1044                     5
# 1                 1.7                  3190                     1
# 2                 4.2                  1155                     2
# 3                 1.2                  1820                     1
# 4                 2.1                  2205                     1
# ...               ...                   ...                   ...
# 54909             0.6                    11                     5
# 54910            10.9                    16                     4
# 54911             3.0                     3                     2
# 54912             5.0                     0                     0
# 54913             1.1                     0                     0
#
#        avg_user_ratings  airport_taxi  travel_sustainable_level  \
# 0              8.900000             0                         4
# 1              7.500000             0                         0
# 2              8.300000             0                         3
# 3              7.100000             0                         0
# 4              7.300000             0                         0
# ...                 ...           ...                       ...
# 54909          8.600000             0                         0
# 54910          9.600000             0                         2
# 54911          8.000000             0                         0
# 54912          7.789035             0                         0
# 54913          7.789035             0                         0
#
#        has_free_cancelation town_location
# 0                     False     Amsterdam
# 1                      True     Amsterdam
# 2                      True     Amsterdam
# 3                      True     Amsterdam
# 4                     False     Amsterdam
# ...                     ...           ...
# 54909                 False      Dortmund
# 54910                 False      Dortmund
# 54911                 False      Dortmund
# 54912                 False      Dortmund
# 54913                 False      Dortmund
#
# [54914 rows x 13 columns]

# %% [markdown]
# ### The last thing we would need to do is divide the df into two seperate df since there are great differences between them.

# %%
df_antwerp = df[df['town_location']=='Antwerp']
df_dortmund = df[df['town_location']=='Dortmund']
df_amsterdam = df[df['town_location']=='Amsterdam']

# %% [markdown]
# 12. We also need to encode 'has_free_cancelation'

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['has_free_cancelation'] = label_encoder.fit_transform(df['has_free_cancelation'])

# %% [markdown]
# #### Now we create a list of these dfs and apply the methods bellow to the dfs

# %%
## now make all code bellow in a function so that i can run in for each df
all_dfs = {"all": df,"Antwerp": df_antwerp, "Dortmund": df_dortmund, "Amsterdam": df_amsterdam}

# %%
import papermill as pm

for single_df in all_dfs:
    all_dfs[single_df]["date"]=all_dfs[single_df]["date"].astype(str)
    df_dict = all_dfs[single_df].to_dict(orient='records')
    print(single_df)
    
    pm.execute_notebook(
        './preprocessing_script.ipynb',
        './output_'+single_df+'.ipynb',
        parameters=dict(df=df_dict,df_name=single_df)
    )
# Out:
# Passed unknown parameter: df
# Passed unknown parameter: df_name
# all
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing: 100%|██████████| 37/37 [03:04<00:00,  4.97s/cell]
# /var/folders/tw/dszf86bn0kjgzxp0v_8g35sc0000gn/T/ipykernel_76584/2119138737.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_dfs[single_df]["date"]=all_dfs[single_df]["date"].astype(str)
# Passed unknown parameter: df
# Passed unknown parameter: df_name
# Antwerp
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing: 100%|██████████| 37/37 [00:52<00:00,  1.42s/cell]
# /var/folders/tw/dszf86bn0kjgzxp0v_8g35sc0000gn/T/ipykernel_76584/2119138737.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_dfs[single_df]["date"]=all_dfs[single_df]["date"].astype(str)
# Passed unknown parameter: df
# Passed unknown parameter: df_name
# Dortmund
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing: 100%|██████████| 37/37 [00:50<00:00,  1.36s/cell]
# /var/folders/tw/dszf86bn0kjgzxp0v_8g35sc0000gn/T/ipykernel_76584/2119138737.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_dfs[single_df]["date"]=all_dfs[single_df]["date"].astype(str)
# Passed unknown parameter: df
# Passed unknown parameter: df_name
# Amsterdam
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Executing: 100%|██████████| 37/37 [00:52<00:00,  1.41s/cell]
